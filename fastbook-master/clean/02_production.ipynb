# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %% [markdown]
# # From Model to Production

# %% [markdown]
# ## The Practice of Deep Learning

# %% [markdown]
# ### Starting Your Project

# %% [markdown]
# ### The State of Deep Learning

# %% [markdown]
# #### Computer vision

# %% [markdown]
# #### Text (natural language processing)

# %% [markdown]
# #### Combining text and images

# %% [markdown]
# #### Tabular data

# %% [markdown]
# #### Recommendation systems

# %% [markdown]
# #### Other data types

# %% [markdown]
# ### The Drivetrain Approach

# %% [markdown]
# ## Gathering Data

# %% [markdown]
# # clean
# To download images with Bing Image Search, sign up at [Microsoft Azure](https://azure.microsoft.com/en-us/services/cognitive-services/bing-web-search-api/) for a free account. You will be given a key, which you can copy and enter in a cell as follows (replacing 'XXX' with your key and executing it):

# %%
import os
key = os.environ.get('AZURE_SEARCH_KEY', 'e28cacd5f1574a2ea30b18b454b72e9d')

# %%
search_images_bing
# Out:
# <function fastbook.search_images_bing(key, term, min_sz=128, max_images=150)>

# %%
results = search_images_bing(key, 'calathea ornata')
ims = results.attrgot('contentUrl')
len(ims)
# Out:
# 150

# %%
#hide
ims = ['http://3.bp.blogspot.com/-S1scRCkI3vY/UHzV2kucsPI/AAAAAAAAA-k/YQ5UzHEm9Ss/s1600/Grizzly%2BBear%2BWildlife.jpg']

# %%
dest = 'plants/calathea ornata.jpg'
download_url(ims[0], dest)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1794048' class='' max='1790431' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.20% [1794048/1790431 00:00<00:00]
#     </div>
# Path('plants/calathea ornata.jpg')

# %%
im = Image.open(dest)
im.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGBA size=96x128 at 0x7F643B03BB50>

# %%
plant_types = 'calathea ornata','Calathea insignis',"Ficus lyrata","Monstera deliciosa","Orchid","Chamaedorea","Dieffenbachia"  
 
path = Path('plant_types')

# %%
if not path.exists():
    path.mkdir()
    for o in plant_types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o} plant')
        download_images(dest, urls=results.attrgot('contentUrl'))

# %%
fns = get_image_files(path)
fns
# Out:
# (#991) [Path('plant_types/Dieffenbachia/00000139.jpg'),Path('plant_types/Dieffenbachia/00000116.jpg'),Path('plant_types/Dieffenbachia/00000077.jpg'),Path('plant_types/Dieffenbachia/00000128.jpg'),Path('plant_types/Dieffenbachia/00000084.jpg'),Path('plant_types/Dieffenbachia/00000090.jpg'),Path('plant_types/Dieffenbachia/00000057.png'),Path('plant_types/Dieffenbachia/00000026.jpeg'),Path('plant_types/Dieffenbachia/00000011.jpg'),Path('plant_types/Dieffenbachia/00000091.jpg')...]

# %%
print(path)
# Out:
# plant_types

# %%
failed = verify_images(fns)
failed

# %%
failed.map(Path.unlink);

# %% [markdown]
# ### Sidebar: Getting Help in Jupyter Notebooks

# %% [markdown]
# ### End sidebar

# %% [markdown]
# ## From Data to DataLoaders

# %%
plants = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
plants = plants.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = plants.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
plants = plants.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = plants.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
plants = plants.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = plants.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %% [markdown]
# ### Data Augmentation

# %%
plants = plants.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = plants.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %% [markdown]
# ## Training Your Model, and Using It to Clean Your Data

# %%
plants = plants.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = plants.dataloaders(path)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.192858</td>
#       <td>0.784651</td>
#       <td>0.255208</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.752207</td>
#       <td>0.332651</td>
#       <td>0.093750</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.551114</td>
#       <td>0.211475</td>
#       <td>0.046875</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.392961</td>
#       <td>0.192904</td>
#       <td>0.052083</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.306720</td>
#       <td>0.186495</td>
#       <td>0.052083</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
interp.plot_top_losses(5, nrows=1)

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py:962: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# VBox(children=(Dropdown(options=('Calathea insignis', 'Chamaedorea', 'Dieffenbachia', 'Ficus lyrata', 'Monster…

# %%
#hide
for idx in cleaner.delete(): cleaner.fns[idx].unlink()
# for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %% [markdown]
# ## Turning Your Model into an Online Application

# %% [markdown]
# ### Using the Model for Inference

# %%
learn.export()

# %%
path = Path('C:\\Users\\omer\\Documents\\GitHub\\fast_ai\\fastbook-master\\clean\\export.pkl')
#path.ls(file_exts='.pkl')

# %%
import pathlib
temp = pathlib.PosixPath
pathlib.PosixPath = pathlib.WindowsPath
learn_inf = load_learner('C:/Users/omer/Documents/GitHub/fast_ai/fastbook-master/clean/export.pkl')
pathlib.PosixPath = temp

# %%
learn_inf.predict('/home/omer/plant.jpeg')
# Out:
# ('calathea ornata',
#  tensor(6),
#  tensor([4.0660e-09, 9.8004e-08, 2.3887e-10, 7.3094e-10, 6.7875e-09, 2.1346e-08, 1.0000e+00]))

# %%
learn_inf.dls.vocab
# Out:
# ['Calathea insignis', 'Chamaedorea', 'Dieffenbachia', 'Ficus lyrata', 'Monstera deliciosa', 'Orchid', 'calathea ornata']

# %% [markdown]
# ### Creating a Notebook App from the Model

# %%
import ipywidgets as widgets
from fastbook import *
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
img = PILImage.create(btn_upload.data[-1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-82db33b3197c> in <module>
# ----> 1 img = PILImage.create(btn_upload.data[-1])
#
# IndexError: list index out of range

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_619943/1347121715.py in <module>
#       1 lbl_pred = widgets.Label()
# ----> 2 lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
#       3 lbl_pred
#
# NameError: name 'pred' is not defined

# %%
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={}, description='Upload'), Button(descriptio…

# %% [markdown]
# ### Turning Your Notebook into a Real App

# %%
#hide
# !pip install --user voila 
# !jupyter serverextension enable --sys-prefix voila
# Out:
# Requirement already satisfied: voila in /home/omer/.local/lib/python3.8/site-packages (0.2.16)
# Requirement already satisfied: nbclient<0.6,>=0.4.0 in /home/omer/.local/lib/python3.8/site-packages (from voila) (0.5.3)
# Requirement already satisfied: jupyter-client<7,>=6.1.3 in /home/omer/.local/lib/python3.8/site-packages (from voila) (6.1.12)
# Requirement already satisfied: nbconvert<7,>=6.0.0 in /home/omer/.local/lib/python3.8/site-packages (from voila) (6.2.0)
# Requirement already satisfied: jupyter-server<2.0.0,>=0.3.0 in /home/omer/.local/lib/python3.8/site-packages (from voila) (1.10.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/lib/python3/dist-packages (from jupyter-client<7,>=6.1.3->voila) (2.7.3)
# Requirement already satisfied: tornado>=4.1 in /home/omer/.local/lib/python3.8/site-packages (from jupyter-client<7,>=6.1.3->voila) (6.1)
# Requirement already satisfied: pyzmq>=13 in /home/omer/.local/lib/python3.8/site-packages (from jupyter-client<7,>=6.1.3->voila) (22.2.0)
# Requirement already satisfied: traitlets in /home/omer/.local/lib/python3.8/site-packages (from jupyter-client<7,>=6.1.3->voila) (5.0.5)
# Requirement already satisfied: jupyter-core>=4.6.0 in /home/omer/.local/lib/python3.8/site-packages (from jupyter-client<7,>=6.1.3->voila) (4.7.1)
# Requirement already satisfied: Send2Trash in /home/omer/.local/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (1.7.1)
# Requirement already satisfied: nbformat in /home/omer/.local/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (5.1.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/omer/.local/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.10.1)
# Requirement already satisfied: prometheus-client in /home/omer/.local/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.11.0)
# Requirement already satisfied: requests-unixsocket in /usr/lib/python3/dist-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.2.0)
# Requirement already satisfied: jinja2 in /home/omer/.local/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (3.0.1)
# Requirement already satisfied: websocket-client in /home/omer/.local/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (1.1.0)
# Requirement already satisfied: ipython-genutils in /usr/lib/python3/dist-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.2.0)
# Requirement already satisfied: argon2-cffi in /home/omer/.local/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (20.1.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /home/omer/.local/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (3.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/omer/.local/lib/python3.8/site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila) (2.8)
# Requirement already satisfied: nest-asyncio in /home/omer/.local/lib/python3.8/site-packages (from nbclient<0.6,>=0.4.0->voila) (1.5.1)
# Requirement already satisfied: async-generator in /home/omer/.local/lib/python3.8/site-packages (from nbclient<0.6,>=0.4.0->voila) (1.10)
# Requirement already satisfied: jupyterlab-pygments in /home/omer/.local/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/lib/python3/dist-packages (from nbconvert<7,>=6.0.0->voila) (0.3)
# Requirement already satisfied: defusedxml in /home/omer/.local/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.7.1)
# Requirement already satisfied: bleach in /home/omer/.local/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (4.0.0)
# Requirement already satisfied: testpath in /home/omer/.local/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/omer/.local/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/omer/.local/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (1.4.3)
# Requirement already satisfied: pygments>=2.4.1 in /home/omer/.local/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (2.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/omer/.local/lib/python3.8/site-packages (from jinja2->jupyter-server<2.0.0,>=0.3.0->voila) (2.0.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/omer/.local/lib/python3.8/site-packages (from nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/omer/.local/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (0.18.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (45.2.0)
# Requirement already satisfied: six>=1.11.0 in /usr/lib/python3/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (1.14.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/omer/.local/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (21.2.0)
# Requirement already satisfied: ptyprocess in /home/omer/.local/lib/python3.8/site-packages (from terminado>=0.8.3->jupyter-server<2.0.0,>=0.3.0->voila) (0.7.0)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from argon2-cffi->jupyter-server<2.0.0,>=0.3.0->voila) (1.14.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server<2.0.0,>=0.3.0->voila) (2.20)
# Requirement already satisfied: packaging in /home/omer/.local/lib/python3.8/site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (21.0)
# Requirement already satisfied: webencodings in /home/omer/.local/lib/python3.8/site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->bleach->nbconvert<7,>=6.0.0->voila) (2.4.7)
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Enabling: voila
# - Writing config: /usr/etc/jupyter
# Traceback (most recent call last):
#   File "/home/omer/.local/bin/jupyter-serverextension", line 8, in <module>
#     sys.exit(main())
#   File "/home/omer/.local/lib/python3.8/site-packages/jupyter_core/application.py", line 254, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/home/omer/.local/lib/python3.8/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/home/omer/.local/lib/python3.8/site-packages/notebook/serverextensions.py", line 291, in start
#     super().start()
#   File "/home/omer/.local/lib/python3.8/site-packages/jupyter_core/application.py", line 243, in start
#     self.subapp.start()
#   File "/home/omer/.local/lib/python3.8/site-packages/notebook/serverextensions.py", line 210, in start
#     self.toggle_server_extension(arg)
#   File "/home/omer/.local/lib/python3.8/site-packages/notebook/serverextensions.py", line 181, in toggle_server_extension
#     toggle_serverextension_python(
#   File "/home/omer/.local/lib/python3.8/site-packages/notebook/serverextensions.py", line 71, in toggle_serverextension_python
#     cm.update("jupyter_notebook_config", cfg)
#   File "/home/omer/.local/lib/python3.8/site-packages/notebook/config_manager.py", line 131, in update
#     self.set(section_name, data)
#   File "/home/omer/.local/lib/python3.8/site-packages/notebook/config_manager.py", line 108, in set
#     self.ensure_config_dir_exists()
#   File "/home/omer/.local/lib/python3.8/site-packages/notebook/config_manager.py", line 65, in ensure_config_dir_exists
#     os.makedirs(self.config_dir, 0o755)
#   File "/usr/lib/python3.8/os.py", line 213, in makedirs
#     makedirs(head, exist_ok=exist_ok)
#   File "/usr/lib/python3.8/os.py", line 223, in makedirs
#     mkdir(name, mode)
# PermissionError: [Errno 13] Permission denied: '/usr/etc'

# %% [markdown]
# ### Deploying your app

# %% [markdown]
# ## How to Avoid Disaster

# %% [markdown]
# ### Unforeseen Consequences and Feedback Loops

# %% [markdown]
# ## Get Writing!

# %% [markdown]
# ## Questionnaire

# %% [markdown]
# 1. Provide an example of where the bear classification model might work poorly in production, due to structural or style differences in the training data.
# 1. Where do text models currently have a major deficiency?
# 1. What are possible negative societal implications of text generation models?
# 1. In situations where a model might make mistakes, and those mistakes could be harmful, what is a good alternative to automating a process?
# 1. What kind of tabular data is deep learning particularly good at?
# 1. What's a key downside of directly using a deep learning model for recommendation systems?
# 1. What are the steps of the Drivetrain Approach?
# 1. How do the steps of the Drivetrain Approach map to a recommendation system?
# 1. Create an image recognition model using data you curate, and deploy it on the web.
# 1. What is `DataLoaders`?
# 1. What four things do we need to tell fastai to create `DataLoaders`?
# 1. What does the `splitter` parameter to `DataBlock` do?
# 1. How do we ensure a random split always gives the same validation set?
# 1. What letters are often used to signify the independent and dependent variables?
# 1. What's the difference between the crop, pad, and squish resize approaches? When might you choose one over the others?
# 1. What is data augmentation? Why is it needed?
# 1. What is the difference between `item_tfms` and `batch_tfms`?
# 1. What is a confusion matrix?
# 1. What does `export` save?
# 1. What is it called when we use a model for getting predictions, instead of training?
# 1. What are IPython widgets?
# 1. When might you want to use CPU for deployment? When might GPU be better?
# 1. What are the downsides of deploying your app to a server, instead of to a client (or edge) device such as a phone or PC?
# 1. What are three examples of problems that could occur when rolling out a bear warning system in practice?
# 1. What is "out-of-domain data"?
# 1. What is "domain shift"?
# 1. What are the three steps in the deployment process?

# %% [markdown]
# ### Further Research

# %% [markdown]
# 1. Consider how the Drivetrain Approach maps to a project or problem you're interested in.
# 1. When might it be best to avoid certain types of data augmentation?
# 1. For a project you're interested in applying deep learning to, consider the thought experiment "What would happen if it went really, really well?"
# 1. Start a blog, and write your first blog post. For instance, write about what you think deep learning might be useful for in a domain you're interested in.
